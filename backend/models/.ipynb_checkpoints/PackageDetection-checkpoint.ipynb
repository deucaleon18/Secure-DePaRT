# %%
import tensorflow as tf
import os

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import cv2
import imghdr

# %%
data_dir = 'data'

# %%
image_exts = ['jpeg','jpg','bmp', 'png']

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 185 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
data_iterator

# %%
batch= data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)+1

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
train
# Out:
# <TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 4/4 [==============================] - 14s 563ms/step - loss: 0.8856 - accuracy: 0.5078 - val_loss: 0.6920 - val_accuracy: 0.4688
# Epoch 2/20
# 4/4 [==============================] - 2s 439ms/step - loss: 0.6869 - accuracy: 0.5703 - val_loss: 0.6591 - val_accuracy: 0.7188
# Epoch 3/20
# 4/4 [==============================] - 2s 340ms/step - loss: 0.6409 - accuracy: 0.7422 - val_loss: 0.6005 - val_accuracy: 0.6250
# Epoch 4/20
# 4/4 [==============================] - 2s 371ms/step - loss: 0.6005 - accuracy: 0.6797 - val_loss: 0.5210 - val_accuracy: 0.8125
# Epoch 5/20
# 4/4 [==============================] - 2s 363ms/step - loss: 0.4923 - accuracy: 0.8047 - val_loss: 0.6140 - val_accuracy: 0.5938
# Epoch 6/20
# 4/4 [==============================] - 2s 348ms/step - loss: 0.5118 - accuracy: 0.7656 - val_loss: 0.4830 - val_accuracy: 0.7500
# Epoch 7/20
# 4/4 [==============================] - 2s 366ms/step - loss: 0.4018 - accuracy: 0.8359 - val_loss: 0.3935 - val_accuracy: 0.7812
# Epoch 8/20
# 4/4 [==============================] - 2s 357ms/step - loss: 0.3331 - accuracy: 0.8672 - val_loss: 0.2934 - val_accuracy: 0.8750
# Epoch 9/20
# 4/4 [==============================] - 2s 364ms/step - loss: 0.2337 - accuracy: 0.8984 - val_loss: 0.1666 - val_accuracy: 0.9688
# Epoch 10/20
# 4/4 [==============================] - 2s 361ms/step - loss: 0.1702 - accuracy: 0.9453 - val_loss: 0.3894 - val_accuracy: 0.8125
# Epoch 11/20
# 4/4 [==============================] - 2s 372ms/step - loss: 0.2378 - accuracy: 0.8672 - val_loss: 0.0953 - val_accuracy: 1.0000
# Epoch 12/20
# 4/4 [==============================] - 2s 362ms/step - loss: 0.2358 - accuracy: 0.9219 - val_loss: 0.1296 - val_accuracy: 1.0000
# Epoch 13/20
# 4/4 [==============================] - 2s 341ms/step - loss: 0.2005 - accuracy: 0.9453 - val_loss: 0.1701 - val_accuracy: 0.9688
# Epoch 14/20
# 4/4 [==============================] - 2s 355ms/step - loss: 0.1735 - accuracy: 0.9844 - val_loss: 0.0849 - val_accuracy: 1.0000
# Epoch 15/20
# 4/4 [==============================] - 2s 348ms/step - loss: 0.1254 - accuracy: 0.9766 - val_loss: 0.0528 - val_accuracy: 1.0000
# Epoch 16/20
# 4/4 [==============================] - 2s 366ms/step - loss: 0.0829 - accuracy: 0.9844 - val_loss: 0.0787 - val_accuracy: 0.9688
# Epoch 17/20
# 4/4 [==============================] - 2s 363ms/step - loss: 0.0745 - accuracy: 0.9766 - val_loss: 0.0314 - val_accuracy: 1.0000
# Epoch 18/20
# 4/4 [==============================] - 2s 367ms/step - loss: 0.0480 - accuracy: 0.9922 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 19/20
# 4/4 [==============================] - 2s 353ms/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 20/20
# 4/4 [==============================] - 2s 372ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 390ms/step

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32)

# %%
import cv2

# %%
save_path = './model.h5'
model.save(save_path)

# %%
import keras

# %%
cap = cv2.VideoCapture(0)

while(True):
    ret, frame = cap.read()
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2BGRA)

    cv2.imshow('frame', rgb)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        out = cv2.imwrite('capture.jpg', frame)
        break

cap.release()
cv2.destroyAllWindows()
