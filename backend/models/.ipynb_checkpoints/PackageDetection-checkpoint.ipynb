# %%
import tensorflow as tf
import os
import time

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import cv2
import imghdr

# %%
data_dir = 'archive'

# %%
image_exts = ['jpeg','jpg','bmp', 'png']

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('archive')
# Out:
# Found 400 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
data_iterator

# %%
batch= data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)+1

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
train
# Out:
# <TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/2"

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=40, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/40
# 9/9 [==============================] - 12s 276ms/step - loss: 0.7807 - accuracy: 0.5069 - val_loss: 0.6918 - val_accuracy: 0.5312
# Epoch 2/40
# 9/9 [==============================] - 2s 220ms/step - loss: 0.6931 - accuracy: 0.5139 - val_loss: 0.6918 - val_accuracy: 0.5000
# Epoch 3/40
# 9/9 [==============================] - 2s 199ms/step - loss: 0.6926 - accuracy: 0.5208 - val_loss: 0.6938 - val_accuracy: 0.4375
# Epoch 4/40
# 9/9 [==============================] - 2s 199ms/step - loss: 0.6917 - accuracy: 0.5312 - val_loss: 0.6875 - val_accuracy: 0.6094
# Epoch 5/40
# 9/9 [==============================] - 2s 205ms/step - loss: 0.6872 - accuracy: 0.5521 - val_loss: 0.6962 - val_accuracy: 0.5156
# Epoch 6/40
# 9/9 [==============================] - 2s 201ms/step - loss: 0.6867 - accuracy: 0.5521 - val_loss: 0.6546 - val_accuracy: 0.6719
# Epoch 7/40
# 9/9 [==============================] - 2s 212ms/step - loss: 0.6804 - accuracy: 0.5590 - val_loss: 0.6906 - val_accuracy: 0.5156
# Epoch 8/40
# 9/9 [==============================] - 2s 197ms/step - loss: 0.6761 - accuracy: 0.5729 - val_loss: 0.6476 - val_accuracy: 0.5625
# Epoch 9/40
# 9/9 [==============================] - 2s 196ms/step - loss: 0.6702 - accuracy: 0.6181 - val_loss: 0.6564 - val_accuracy: 0.6094
# Epoch 10/40
# 9/9 [==============================] - 3s 207ms/step - loss: 0.6738 - accuracy: 0.5868 - val_loss: 0.6781 - val_accuracy: 0.5469
# Epoch 11/40
# 9/9 [==============================] - 2s 204ms/step - loss: 0.6567 - accuracy: 0.5938 - val_loss: 0.6776 - val_accuracy: 0.6250
# Epoch 12/40
# 9/9 [==============================] - 3s 218ms/step - loss: 0.6582 - accuracy: 0.6181 - val_loss: 0.6053 - val_accuracy: 0.7344
# Epoch 13/40
# 9/9 [==============================] - 2s 194ms/step - loss: 0.6398 - accuracy: 0.6736 - val_loss: 0.6382 - val_accuracy: 0.6875
# Epoch 14/40
# 9/9 [==============================] - 2s 200ms/step - loss: 0.6233 - accuracy: 0.6667 - val_loss: 0.6350 - val_accuracy: 0.6719
# Epoch 15/40
# 9/9 [==============================] - 2s 205ms/step - loss: 0.6147 - accuracy: 0.6736 - val_loss: 0.5556 - val_accuracy: 0.7344
# Epoch 16/40
# 9/9 [==============================] - 2s 208ms/step - loss: 0.5708 - accuracy: 0.6979 - val_loss: 0.4312 - val_accuracy: 0.7969
# Epoch 17/40
# 9/9 [==============================] - 2s 210ms/step - loss: 0.5309 - accuracy: 0.7465 - val_loss: 0.4774 - val_accuracy: 0.7344
# Epoch 18/40
# 9/9 [==============================] - 2s 213ms/step - loss: 0.4878 - accuracy: 0.7674 - val_loss: 0.3697 - val_accuracy: 0.8438
# Epoch 19/40
# 9/9 [==============================] - 2s 208ms/step - loss: 0.4442 - accuracy: 0.7986 - val_loss: 0.4301 - val_accuracy: 0.8281
# Epoch 20/40
# 9/9 [==============================] - 2s 211ms/step - loss: 0.4126 - accuracy: 0.8333 - val_loss: 0.3906 - val_accuracy: 0.8281
# Epoch 21/40
# 9/9 [==============================] - 2s 204ms/step - loss: 0.3722 - accuracy: 0.8194 - val_loss: 0.3529 - val_accuracy: 0.8594
# Epoch 22/40
# 9/9 [==============================] - 3s 252ms/step - loss: 0.3317 - accuracy: 0.8715 - val_loss: 0.2700 - val_accuracy: 0.8906
# Epoch 23/40
# 9/9 [==============================] - 2s 210ms/step - loss: 0.2656 - accuracy: 0.8993 - val_loss: 0.1906 - val_accuracy: 0.9219
# Epoch 24/40
# 9/9 [==============================] - 2s 227ms/step - loss: 0.2279 - accuracy: 0.9097 - val_loss: 0.1547 - val_accuracy: 0.9844
# Epoch 25/40
# 9/9 [==============================] - 2s 212ms/step - loss: 0.2328 - accuracy: 0.9410 - val_loss: 0.1110 - val_accuracy: 0.9688
# Epoch 26/40
# 9/9 [==============================] - 2s 206ms/step - loss: 0.1421 - accuracy: 0.9618 - val_loss: 0.1144 - val_accuracy: 0.9688
# Epoch 27/40
# 9/9 [==============================] - 2s 208ms/step - loss: 0.1646 - accuracy: 0.9549 - val_loss: 0.0480 - val_accuracy: 1.0000
# Epoch 28/40
# 9/9 [==============================] - 2s 206ms/step - loss: 0.0949 - accuracy: 0.9757 - val_loss: 0.0460 - val_accuracy: 1.0000
# Epoch 29/40
# 9/9 [==============================] - 2s 210ms/step - loss: 0.0716 - accuracy: 0.9653 - val_loss: 0.0352 - val_accuracy: 0.9844
# Epoch 30/40
# 9/9 [==============================] - 2s 210ms/step - loss: 0.0748 - accuracy: 0.9757 - val_loss: 0.0289 - val_accuracy: 0.9844
# Epoch 31/40
# 9/9 [==============================] - 2s 221ms/step - loss: 0.0679 - accuracy: 0.9757 - val_loss: 0.0482 - val_accuracy: 0.9844
# Epoch 32/40
# 9/9 [==============================] - 2s 209ms/step - loss: 0.0416 - accuracy: 0.9896 - val_loss: 0.0719 - val_accuracy: 0.9844
# Epoch 33/40
# 9/9 [==============================] - 2s 211ms/step - loss: 0.0384 - accuracy: 0.9861 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 34/40
# 9/9 [==============================] - 2s 207ms/step - loss: 0.0333 - accuracy: 0.9861 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 35/40
# 9/9 [==============================] - 2s 205ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 36/40
# 9/9 [==============================] - 2s 204ms/step - loss: 0.0394 - accuracy: 0.9861 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 37/40
# 9/9 [==============================] - 3s 222ms/step - loss: 0.0271 - accuracy: 0.9965 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 38/40
# 9/9 [==============================] - 3s 235ms/step - loss: 0.0166 - accuracy: 0.9965 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 39/40
# 9/9 [==============================] - 2s 211ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 40/40
# 9/9 [==============================] - 2s 207ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 8.2570e-04 - val_accuracy: 1.0000

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 253ms/step

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32)

# %%
import cv2

# %%
img = cv2.imread('packagetest/data/damaged/image.jpeg')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
if yhat > 0.3: 
    print(f'Predicted class is Intact')
else:
    print(f'Predicted class is Damaged')
# Out:
# Predicted class is Intact

# %%
yhat
# Out:
# array([[0.99996126]], dtype=float32)
